# %%
class Suit:
    
    SYMBOLS = {"clubs": "♣", "diamonds": "♦", "hearts": "♥", "spades": "♠"}
    
    def __init__(self, description):
        self._description = description
        self._symbol = Suit.SYMBOLS[description]
    
    @property
    def description(self):
        return self._description
    
    @property
    def symbol(self):
        return self._symbol


class Card:
    
    SPECIAL_CARDS = {11: "Jack", 12: "Queen", 13: "King", 14: "Ace"}
    
    def __init__(self, suit, value):
        self._suit = suit
        self._value = value
    
    @property
    def suit(self):
        return self._suit
    
    @property
    def value(self):
        return self._value
    
    def show(self):
        card_value = self._value
        card_suit = self._suit.description.capitalize()
        suit_symbol = self._suit.symbol
        
        if self.is_special():
            card_description = Card.SPECIAL_CARDS[card_value]
            print(f"{card_description} of {card_suit} {suit_symbol}")
        else:
            print(f"{card_value} of {card_suit} {suit_symbol}")
    
    def is_special(self):
        return self._value >= 11


import random

class Deck:
    
    SUITS = ['clubs', 'diamonds', 'hearts', 'spades']
    
    def __init__(self, is_empty=False):
        self._cards = []
        
        if not is_empty:
            self.build()
    
    @property
    def size(self):
        return len(self._cards)
    
    def build(self):
        for suit in Deck.SUITS:
            for value in range(2,15):
                self._cards.append(Card(Suit(suit), value))
    
    def show(self):
        for card in self._cards:
            card.show()
    
    def shuffle(self):
        random.shuffle(self._cards)
    
    def draw(self):
        if self._cards:
            return self._cards.pop()
        else:
            return None
    def add(self, card):
        self._cards.insert(0, card)
    


class Player:
    
    def __init__(self, name, deck, is_computer=False):
        self.name = name
        self._deck = deck
        self._is_computer = is_computer
    
    @property
    def is_computer(self):
        return self._is_computer
    
    @property
    def deck(self):
        return self._deck
    
    def has_empty_deck(self):
        return self._deck.size == 0
    
    def draw_card(self):
        if not self.has_empty_deck():
            return self._deck.draw()
        else:
            return None
    
    def add_card(self, card):
        self._deck.add(card)
        


class WarCardGame:
    
    PLAYER = 0
    COMPUTER = 1
    TIE = 2
    
    def __init__(self, player, computer, deck):
        self._player = player
        self._computer = computer
        self._deck = deck
        
        self.make_initial_decks()
    
    def make_initial_decks(self):
        self._deck.shuffle()
        self.make_deck(self._player)
        self.make_deck(self._computer)
        
    def make_deck(self, character):
        for _ in range(26):
            card = self._deck.draw()
            character.add_card(card)
    
    def start_battle(self, cards_from_war=None):
        
        print("\n === Let's Start the war ===\n")
        
        player_card = self._player.draw_card()
        computer_card = self._computer.draw_card()
        
        print("Your Card : ")
        player_card.show()
        
        print("\nComputer Card : ")
        computer_card.show()
        
        winner = self.get_round_winner(player_card, computer_card)
        cards_won = self.get_cards_won(player_card,computer_card, cards_from_war)
        
        if winner == WarCardGame.PLAYER:
            print("\nYou won this round!")
            self.add_cards_to_character(self._player, cards_won)
            
        elif winner == WarCardGame.COMPUTER:
            print("\nThe computer won this round!")
            self.add_cards_to_character(self._computer, cards_won)
            
        else:
            print("\nIt's a Tie!. This is War !")
            self.start_war(cards_won)
        
        return winner
    
    def get_round_winner(self, player_card, computer_card):
        if player_card.value > computer_card.value:
            return WarCardGame.PLAYER
        elif computer_card.value > player_card.value:
            return WarCardGame.COMPUTER
        else:
            return WarCardGame.TIE
    
    def get_cards_won(self, player_card, computer_card, previous_cards):
        
        if previous_cards:
            return [player_card, computer_card] + previous_cards
        else:
            return [player_card, computer_card]
    
    def add_cards_to_character(self, character, cards_from_battle):
        for card in cards_from_battle:
            character.add_card(card)
    
    def start_war(self, cards_from_war):
        player_cards = []
        computer_cards  =[]
        
        for _ in range(3):
            player_card = self._player.draw_card()
            computer_card = self._computer.draw_card()
            
            player_cards.append(player_card)
            computer_cards.append(computer_card)
        
        print(f"Six Hidden Cards : XXX XXX")
        
        self.start_battle(player_cards + computer_cards + cards_from_war)
        
    def check_game_over(self):
        if self._player.has_empty_deck():
            print("=====================================")
            print("|         GAME OVER                 |")
            print("=====================================")
            print("Try again! The computer Won.")
            return True
        
        elif self._computer.has_empty_deck():
            print("=====================================")
            print("|         GAME OVER                 |")
            print("=====================================")
            print(f"Excellent, You Won, {self._player.name} Congratulations !!!")
            return True
        
        else:
            return False
    
    def print_stats(self):
        print("\n----")
        print(f"You have {self._player.deck.size} cards on your deck")
        print(f"The computer has {self._computer.deck.size} cards on its deck")
        print("----")
    
    def print_welcome_message(self):
        print("=====================================")
        print("|         WAR CARD GAME             |")
        print("=====================================")        


player = Player("Jhon", Deck(is_empty=True))
computer = Player("Computer", Deck(is_empty=True), is_computer=True)
deck = Deck()

game = WarCardGame(player, computer, deck)

game.print_welcome_message()

while not game.check_game_over():
    game.start_battle()
    game.print_stats()
    
    
    
#     answer = input("\nAre you ready for next round ?. \nPress Enter to continue. \nEnter X to stop. ")
    
#     if answer.lower() == 'x':
#         break
# Out:
# =====================================
# |         WAR CARD GAME             |
# =====================================
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Diamonds ♦
#
# Computer Card :
# Ace of Spades ♠
#
# The computer won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# 6 of Spades ♠
#
# You won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Hearts ♥
#
# Computer Card :
# 2 of Spades ♠
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Diamonds ♦
#
# Computer Card :
# Ace of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Clubs ♣
#
# Computer Card :
# 2 of Hearts ♥
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 3 of Spades ♠
#
# You won this round!
#
# ----
# You have 28 cards on your deck
# The computer has 24 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Hearts ♥
#
# Computer Card :
# Jack of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# Queen of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 8 of Spades ♠
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Hearts ♥
#
# Computer Card :
# Queen of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Hearts ♥
#
# Computer Card :
# 4 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# 5 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Clubs ♣
#
# Computer Card :
# King of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Hearts ♥
#
# Computer Card :
# 7 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Clubs ♣
#
# Computer Card :
# King of Spades ♠
#
# The computer won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Diamonds ♦
#
# Computer Card :
# 5 of Clubs ♣
#
# You won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 4 of Spades ♠
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Diamonds ♦
#
# Computer Card :
# 2 of Clubs ♣
#
# You won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Spades ♠
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# 4 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Clubs ♣
#
# Computer Card :
# 7 of Hearts ♥
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Clubs ♣
#
# Computer Card :
# Ace of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Hearts ♥
#
# Computer Card :
# 6 of Clubs ♣
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Spades ♠
#
# Computer Card :
# Jack of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Clubs ♣
#
# Computer Card :
# Queen of Spades ♠
#
# The computer won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 2 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# 3 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Spades ♠
#
# Computer Card :
# Ace of Spades ♠
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Hearts ♥
#
# Computer Card :
# 8 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Spades ♠
#
# Computer Card :
# Ace of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Clubs ♣
#
# Computer Card :
# 5 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Hearts ♥
#
# Computer Card :
# Jack of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 6 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Spades ♠
#
# Computer Card :
# Queen of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 8 of Hearts ♥
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Spades ♠
#
# Computer Card :
# Queen of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# 3 of Hearts ♥
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Diamonds ♦
#
# Computer Card :
# 4 of Hearts ♥
#
# You won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Diamonds ♦
#
# Computer Card :
# 4 of Clubs ♣
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Clubs ♣
#
# Computer Card :
# King of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 6 of Hearts ♥
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Spades ♠
#
# Computer Card :
# 7 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Diamonds ♦
#
# Computer Card :
# 8 of Clubs ♣
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Clubs ♣
#
# Computer Card :
# King of Spades ♠
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# 5 of Spades ♠
#
# You won this round!
#
# ----
# You have 27 cards on your deck
# The computer has 25 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Diamonds ♦
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 26 cards on your deck
# The computer has 26 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Clubs ♣
#
# Computer Card :
# Jack of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Hearts ♥
#
# Computer Card :
# Ace of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Hearts ♥
#
# Computer Card :
# 10 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Clubs ♣
#
# Computer Card :
# Jack of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 7 of Clubs ♣
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Diamonds ♦
#
# Computer Card :
# Queen of Spades ♠
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# 6 of Spades ♠
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Diamonds ♦
#
# Computer Card :
# Ace of Spades ♠
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Hearts ♥
#
# Computer Card :
# 2 of Spades ♠
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Diamonds ♦
#
# Computer Card :
# Ace of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 3 of Clubs ♣
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# 5 of Hearts ♥
#
# You won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 2 of Hearts ♥
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Hearts ♥
#
# Computer Card :
# Jack of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# 3 of Spades ♠
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Hearts ♥
#
# Computer Card :
# Queen of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Diamonds ♦
#
# Computer Card :
# 8 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Hearts ♥
#
# Computer Card :
# Queen of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Diamonds ♦
#
# Computer Card :
# 5 of Clubs ♣
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Clubs ♣
#
# Computer Card :
# King of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 4 of Spades ♠
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Hearts ♥
#
# Computer Card :
# 7 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Diamonds ♦
#
# Computer Card :
# 2 of Clubs ♣
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Clubs ♣
#
# Computer Card :
# King of Spades ♠
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# 4 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Spades ♠
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 10 of Clubs ♣
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Clubs ♣
#
# Computer Card :
# Jack of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# 7 of Hearts ♥
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Spades ♠
#
# Computer Card :
# Ace of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Hearts ♥
#
# Computer Card :
# 9 of Hearts ♥
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Spades ♠
#
# Computer Card :
# 10 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 6 of Clubs ♣
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Clubs ♣
#
# Computer Card :
# Jack of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# 2 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Hearts ♥
#
# Computer Card :
# Queen of Spades ♠
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 3 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Hearts ♥
#
# Computer Card :
# Ace of Spades ♠
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# 8 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Spades ♠
#
# Computer Card :
# Ace of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Diamonds ♦
#
# Computer Card :
# 8 of Hearts ♥
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Clubs ♣
#
# Computer Card :
# Jack of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 3 of Hearts ♥
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Spades ♠
#
# Computer Card :
# Queen of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Diamonds ♦
#
# Computer Card :
# 5 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Clubs ♣
#
# Computer Card :
# 8 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# 4 of Hearts ♥
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Diamonds ♦
#
# Computer Card :
# Queen of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 4 of Clubs ♣
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Clubs ♣
#
# Computer Card :
# King of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# 6 of Hearts ♥
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Hearts ♥
#
# Computer Card :
# 7 of Spades ♠
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Clubs ♣
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 18 cards on your deck
# The computer has 34 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# 7 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Diamonds ♦
#
# Computer Card :
# Jack of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 6 of Spades ♠
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Diamonds ♦
#
# Computer Card :
# Ace of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# 2 of Spades ♠
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Diamonds ♦
#
# Computer Card :
# 10 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Diamonds ♦
#
# Computer Card :
# 3 of Clubs ♣
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Hearts ♥
#
# Computer Card :
# Jack of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 5 of Hearts ♥
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Hearts ♥
#
# Computer Card :
# Queen of Spades ♠
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Diamonds ♦
#
# Computer Card :
# 2 of Hearts ♥
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Diamonds ♦
#
# Computer Card :
# Ace of Spades ♠
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# 3 of Spades ♠
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Hearts ♥
#
# Computer Card :
# Ace of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 5 of Clubs ♣
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Clubs ♣
#
# Computer Card :
# Jack of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# 4 of Spades ♠
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Hearts ♥
#
# Computer Card :
# Queen of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 2 of Clubs ♣
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Spades ♠
#
# Computer Card :
# 8 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# 4 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Spades ♠
#
# Computer Card :
# Queen of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Diamonds ♦
#
# Computer Card :
# 10 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 15 cards on your deck
# The computer has 37 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Clubs ♣
#
# Computer Card :
# King of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 14 cards on your deck
# The computer has 38 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 6 of Clubs ♣
#
# You won this round!
#
# ----
# You have 15 cards on your deck
# The computer has 37 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Hearts ♥
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 14 cards on your deck
# The computer has 38 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Diamonds ♦
#
# Computer Card :
# 10 of Hearts ♥
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# King of Spades ♠
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 6 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Clubs ♣
#
# Computer Card :
# 7 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# 2 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Diamonds ♦
#
# Computer Card :
# Jack of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 3 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Clubs ♣
#
# Computer Card :
# Ace of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 8 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 23 cards on your deck
# The computer has 29 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# 10 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 22 cards on your deck
# The computer has 30 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Clubs ♣
#
# Computer Card :
# 8 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 21 cards on your deck
# The computer has 31 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# Jack of Diamonds ♦
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Spades ♠
#
# Computer Card :
# Ace of Spades ♠
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 4 of Hearts ♥
#
# You won this round!
#
# ----
# You have 17 cards on your deck
# The computer has 35 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Spades ♠
#
# Computer Card :
# Ace of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 16 cards on your deck
# The computer has 36 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Hearts ♥
#
# Computer Card :
# 4 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 15 cards on your deck
# The computer has 37 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# Jack of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 14 cards on your deck
# The computer has 38 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Spades ♠
#
# Computer Card :
# 6 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 13 cards on your deck
# The computer has 39 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Hearts ♥
#
# Computer Card :
# Queen of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 12 cards on your deck
# The computer has 40 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 6 of Spades ♠
#
# You won this round!
#
# ----
# You have 13 cards on your deck
# The computer has 39 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Clubs ♣
#
# Computer Card :
# 8 of Spades ♠
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Diamonds ♦
#
# Computer Card :
# 10 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 3 of Clubs ♣
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Diamonds ♦
#
# Computer Card :
# King of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 5 of Hearts ♥
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Diamonds ♦
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 2 of Clubs ♣
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Hearts ♥
#
# Computer Card :
# 7 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 4 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Spades ♠
#
# Computer Card :
# Jack of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 6 of Clubs ♣
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Clubs ♣
#
# Computer Card :
# Ace of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 6 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Hearts ♥
#
# Computer Card :
# 10 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 5 of Clubs ♣
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Clubs ♣
#
# Computer Card :
# 8 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 7 of Spades ♠
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Diamonds ♦
#
# Computer Card :
# Ace of Spades ♠
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Clubs ♣
#
# Computer Card :
# 4 of Spades ♠
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Clubs ♣
#
# Computer Card :
# 5 of Spades ♠
#
# You won this round!
#
# ----
# You have 10 cards on your deck
# The computer has 42 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 7 of Hearts ♥
#
# You won this round!
#
# ----
# You have 11 cards on your deck
# The computer has 41 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# 3 of Hearts ♥
#
# You won this round!
#
# ----
# You have 12 cards on your deck
# The computer has 40 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# Queen of Spades ♠
#
# You won this round!
#
# ----
# You have 13 cards on your deck
# The computer has 39 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Clubs ♣
#
# Computer Card :
# 5 of Diamonds ♦
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Spades ♠
#
# Computer Card :
# Ace of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Clubs ♣
#
# Computer Card :
# 2 of Hearts ♥
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Spades ♠
#
# Computer Card :
# 4 of Clubs ♣
#
# You won this round!
#
# ----
# You have 10 cards on your deck
# The computer has 42 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 7 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 11 cards on your deck
# The computer has 41 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Hearts ♥
#
# Computer Card :
# Jack of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 10 cards on your deck
# The computer has 42 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# 3 of Spades ♠
#
# You won this round!
#
# ----
# You have 11 cards on your deck
# The computer has 41 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Hearts ♥
#
# Computer Card :
# 6 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 10 cards on your deck
# The computer has 42 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 9 of Hearts ♥
#
# You won this round!
#
# ----
# You have 11 cards on your deck
# The computer has 41 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Spades ♠
#
# Computer Card :
# Queen of Hearts ♥
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Clubs ♣
#
# Computer Card :
# 10 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 6 cards on your deck
# The computer has 46 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 9 of Spades ♠
#
# You won this round!
#
# ----
# You have 7 cards on your deck
# The computer has 45 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# 2 of Spades ♠
#
# You won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# Queen of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 7 cards on your deck
# The computer has 45 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Spades ♠
#
# Computer Card :
# 9 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 6 cards on your deck
# The computer has 46 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 8 of Clubs ♣
#
# You won this round!
#
# ----
# You have 7 cards on your deck
# The computer has 45 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Hearts ♥
#
# Computer Card :
# 8 of Spades ♠
#
# You won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 3 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# King of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# 8 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 7 cards on your deck
# The computer has 45 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Spades ♠
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 6 cards on your deck
# The computer has 46 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 4 of Hearts ♥
#
# You won this round!
#
# ----
# You have 7 cards on your deck
# The computer has 45 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Clubs ♣
#
# Computer Card :
# 7 of Clubs ♣
#
# You won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Hearts ♥
#
# Computer Card :
# 6 of Spades ♠
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Spades ♠
#
# Computer Card :
# Jack of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 3 of Clubs ♣
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Diamonds ♦
#
# Computer Card :
# Ace of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 5 of Hearts ♥
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Hearts ♥
#
# Computer Card :
# 10 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Clubs ♣
#
# Computer Card :
# 2 of Clubs ♣
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Clubs ♣
#
# Computer Card :
# 8 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Hearts ♥
#
# Computer Card :
# 4 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Spades ♠
#
# Computer Card :
# Ace of Spades ♠
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 4 of Spades ♠
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Clubs ♣
#
# Computer Card :
# Ace of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# Queen of Diamonds ♦
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Hearts ♥
#
# Computer Card :
# 7 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Clubs ♣
#
# Computer Card :
# 9 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 7 cards on your deck
# The computer has 45 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Clubs ♣
#
# Computer Card :
# Jack of Spades ♠
#
# The computer won this round!
#
# ----
# You have 6 cards on your deck
# The computer has 46 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Hearts ♥
#
# Computer Card :
# Jack of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 5 cards on your deck
# The computer has 47 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Diamonds ♦
#
# Computer Card :
# King of Spades ♠
#
# The computer won this round!
#
# ----
# You have 4 cards on your deck
# The computer has 48 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 5 of Clubs ♣
#
# You won this round!
#
# ----
# You have 5 cards on your deck
# The computer has 47 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Spades ♠
#
# Computer Card :
# 5 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 4 cards on your deck
# The computer has 48 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 7 of Hearts ♥
#
# You won this round!
#
# ----
# You have 5 cards on your deck
# The computer has 47 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# Jack of Hearts ♥
#
# You won this round!
#
# ----
# You have 6 cards on your deck
# The computer has 46 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 3 of Hearts ♥
#
# You won this round!
#
# ----
# You have 7 cards on your deck
# The computer has 45 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Clubs ♣
#
# Computer Card :
# 6 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 6 cards on your deck
# The computer has 46 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 4 of Clubs ♣
#
# You won this round!
#
# ----
# You have 7 cards on your deck
# The computer has 45 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Hearts ♥
#
# Computer Card :
# 10 of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 6 cards on your deck
# The computer has 46 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 6 of Clubs ♣
#
# You won this round!
#
# ----
# You have 7 cards on your deck
# The computer has 45 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Hearts ♥
#
# Computer Card :
# 2 of Hearts ♥
#
# You won this round!
#
# ----
# You have 8 cards on your deck
# The computer has 44 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 5 of Spades ♠
#
# You won this round!
#
# ----
# You have 9 cards on your deck
# The computer has 43 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Hearts ♥
#
# Computer Card :
# 2 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 10 cards on your deck
# The computer has 42 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 10 of Clubs ♣
#
# You won this round!
#
# ----
# You have 11 cards on your deck
# The computer has 41 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Clubs ♣
#
# Computer Card :
# 10 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 10 cards on your deck
# The computer has 42 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# Queen of Spades ♠
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 3 of Spades ♠
#
# You won this round!
#
# ----
# You have 15 cards on your deck
# The computer has 37 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Spades ♠
#
# Computer Card :
# 9 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 14 cards on your deck
# The computer has 38 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Hearts ♥
#
# Computer Card :
# 9 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 13 cards on your deck
# The computer has 39 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Diamonds ♦
#
# Computer Card :
# King of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 12 cards on your deck
# The computer has 40 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 7 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 13 cards on your deck
# The computer has 39 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Clubs ♣
#
# Computer Card :
# 8 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 14 cards on your deck
# The computer has 38 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 2 of Spades ♠
#
# You won this round!
#
# ----
# You have 15 cards on your deck
# The computer has 37 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Spades ♠
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 14 cards on your deck
# The computer has 38 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Clubs ♣
#
# Computer Card :
# 8 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 13 cards on your deck
# The computer has 39 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Hearts ♥
#
# Computer Card :
# Jack of Clubs ♣
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Clubs ♣
#
# Computer Card :
# 10 of Spades ♠
#
# You won this round!
#
# ----
# You have 18 cards on your deck
# The computer has 34 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 7 of Clubs ♣
#
# You won this round!
#
# ----
# You have 19 cards on your deck
# The computer has 33 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Spades ♠
#
# Computer Card :
# 8 of Hearts ♥
#
# You won this round!
#
# ----
# You have 20 cards on your deck
# The computer has 32 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# 6 of Spades ♠
#
# You won this round!
#
# ----
# You have 21 cards on your deck
# The computer has 31 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# Ace of Spades ♠
#
# The computer won this round!
#
# ----
# You have 20 cards on your deck
# The computer has 32 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Clubs ♣
#
# Computer Card :
# 3 of Clubs ♣
#
# You won this round!
#
# ----
# You have 21 cards on your deck
# The computer has 31 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Diamonds ♦
#
# Computer Card :
# Ace of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 20 cards on your deck
# The computer has 32 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Clubs ♣
#
# Computer Card :
# 5 of Hearts ♥
#
# You won this round!
#
# ----
# You have 21 cards on your deck
# The computer has 31 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Spades ♠
#
# Computer Card :
# 7 of Spades ♠
#
# The computer won this round!
#
# ----
# You have 20 cards on your deck
# The computer has 32 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Clubs ♣
#
# Computer Card :
# 8 of Clubs ♣
#
# You won this round!
#
# ----
# You have 21 cards on your deck
# The computer has 31 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Spades ♠
#
# ...
# 9 of Diamonds ♦
#
# Computer Card :
# 9 of Spades ♠
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Hearts ♥
#
# Computer Card :
# 3 of Spades ♠
#
# You won this round!
#
# ----
# You have 33 cards on your deck
# The computer has 19 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Clubs ♣
#
# Computer Card :
# 6 of Spades ♠
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Diamonds ♦
#
# Computer Card :
# King of Spades ♠
#
# The computer won this round!
#
# ----
# You have 28 cards on your deck
# The computer has 24 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# 4 of Hearts ♥
#
# You won this round!
#
# ----
# You have 29 cards on your deck
# The computer has 23 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Diamonds ♦
#
# Computer Card :
# Ace of Hearts ♥
#
# The computer won this round!
#
# ----
# You have 28 cards on your deck
# The computer has 24 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Hearts ♥
#
# Computer Card :
# 6 of Hearts ♥
#
# You won this round!
#
# ----
# You have 29 cards on your deck
# The computer has 23 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Clubs ♣
#
# Computer Card :
# King of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 28 cards on your deck
# The computer has 24 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Diamonds ♦
#
# Computer Card :
# 5 of Hearts ♥
#
# You won this round!
#
# ----
# You have 29 cards on your deck
# The computer has 23 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# 7 of Clubs ♣
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Clubs ♣
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Clubs ♣
#
# Computer Card :
# 7 of Hearts ♥
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Spades ♠
#
# Computer Card :
# 9 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Clubs ♣
#
# Computer Card :
# 9 of Hearts ♥
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Diamonds ♦
#
# Computer Card :
# Jack of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Spades ♠
#
# Computer Card :
# 2 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Spades ♠
#
# Computer Card :
# King of Spades ♠
#
# The computer won this round!
#
# ----
# You have 24 cards on your deck
# The computer has 28 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 10 of Clubs ♣
#
# You won this round!
#
# ----
# You have 25 cards on your deck
# The computer has 27 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Clubs ♣
#
# Computer Card :
# 3 of Hearts ♥
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Hearts ♥
#
# Computer Card :
# 5 of Clubs ♣
#
# You won this round!
#
# ----
# You have 30 cards on your deck
# The computer has 22 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# 6 of Clubs ♣
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Diamonds ♦
#
# Computer Card :
# 8 of Clubs ♣
#
# You won this round!
#
# ----
# You have 35 cards on your deck
# The computer has 17 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# King of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 34 cards on your deck
# The computer has 18 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# 2 of Clubs ♣
#
# You won this round!
#
# ----
# You have 35 cards on your deck
# The computer has 17 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Hearts ♥
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 34 cards on your deck
# The computer has 18 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Hearts ♥
#
# Computer Card :
# 8 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 35 cards on your deck
# The computer has 17 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Hearts ♥
#
# Computer Card :
# 2 of Spades ♠
#
# You won this round!
#
# ----
# You have 36 cards on your deck
# The computer has 16 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Diamonds ♦
#
# Computer Card :
# 10 of Spades ♠
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Clubs ♣
#
# Computer Card :
# 7 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 41 cards on your deck
# The computer has 11 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Hearts ♥
#
# Computer Card :
# 7 of Clubs ♣
#
# You won this round!
#
# ----
# You have 42 cards on your deck
# The computer has 10 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Spades ♠
#
# Computer Card :
# 4 of Spades ♠
#
# You won this round!
#
# ----
# You have 43 cards on your deck
# The computer has 9 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Diamonds ♦
#
# Computer Card :
# 9 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 42 cards on your deck
# The computer has 10 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# 5 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 43 cards on your deck
# The computer has 9 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Clubs ♣
#
# Computer Card :
# Jack of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 42 cards on your deck
# The computer has 10 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Hearts ♥
#
# Computer Card :
# 7 of Spades ♠
#
# You won this round!
#
# ----
# You have 43 cards on your deck
# The computer has 9 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Clubs ♣
#
# Computer Card :
# King of Spades ♠
#
# The computer won this round!
#
# ----
# You have 42 cards on your deck
# The computer has 10 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Hearts ♥
#
# Computer Card :
# 9 of Spades ♠
#
# You won this round!
#
# ----
# You have 43 cards on your deck
# The computer has 9 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Spades ♠
#
# Computer Card :
# King of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 42 cards on your deck
# The computer has 10 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Spades ♠
#
# Computer Card :
# 4 of Hearts ♥
#
# You won this round!
#
# ----
# You have 43 cards on your deck
# The computer has 9 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Diamonds ♦
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 42 cards on your deck
# The computer has 10 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Hearts ♥
#
# Computer Card :
# 2 of Diamonds ♦
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Diamonds ♦
#
# Computer Card :
# 5 of Clubs ♣
#
# You won this round!
#
# ----
# You have 47 cards on your deck
# The computer has 5 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Clubs ♣
#
# Computer Card :
# King of Spades ♠
#
# The computer won this round!
#
# ----
# You have 46 cards on your deck
# The computer has 6 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Ace of Spades ♠
#
# Computer Card :
# 3 of Spades ♠
#
# You won this round!
#
# ----
# You have 47 cards on your deck
# The computer has 5 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Clubs ♣
#
# Computer Card :
# King of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 46 cards on your deck
# The computer has 6 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Ace of Diamonds ♦
#
# Computer Card :
# King of Diamonds ♦
#
# You won this round!
#
# ----
# You have 47 cards on your deck
# The computer has 5 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Spades ♠
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 46 cards on your deck
# The computer has 6 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Diamonds ♦
#
# Computer Card :
# 8 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 45 cards on your deck
# The computer has 7 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Ace of Hearts ♥
#
# Computer Card :
# King of Spades ♠
#
# You won this round!
#
# ----
# You have 46 cards on your deck
# The computer has 6 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Diamonds ♦
#
# Computer Card :
# 4 of Clubs ♣
#
# You won this round!
#
# ----
# You have 47 cards on your deck
# The computer has 5 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 6 of Clubs ♣
#
# Computer Card :
# King of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 46 cards on your deck
# The computer has 6 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Spades ♠
#
# Computer Card :
# 6 of Spades ♠
#
# You won this round!
#
# ----
# You have 47 cards on your deck
# The computer has 5 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Clubs ♣
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 46 cards on your deck
# The computer has 6 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Jack of Hearts ♥
#
# Computer Card :
# 3 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 47 cards on your deck
# The computer has 5 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Diamonds ♦
#
# Computer Card :
# 8 of Clubs ♣
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Diamonds ♦
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 42 cards on your deck
# The computer has 10 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Hearts ♥
#
# Computer Card :
# 7 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 41 cards on your deck
# The computer has 11 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Clubs ♣
#
# Computer Card :
# Ace of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 40 cards on your deck
# The computer has 12 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Hearts ♥
#
# Computer Card :
# 6 of Hearts ♥
#
# You won this round!
#
# ----
# You have 41 cards on your deck
# The computer has 11 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Diamonds ♦
#
# Computer Card :
# 2 of Spades ♠
#
# You won this round!
#
# ----
# You have 42 cards on your deck
# The computer has 10 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# King of Hearts ♥
#
# Computer Card :
# Jack of Clubs ♣
#
# You won this round!
#
# ----
# You have 43 cards on your deck
# The computer has 9 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Hearts ♥
#
# Computer Card :
# 6 of Clubs ♣
#
# You won this round!
#
# ----
# You have 44 cards on your deck
# The computer has 8 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Diamonds ♦
#
# Computer Card :
# King of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 43 cards on your deck
# The computer has 9 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 10 of Spades ♠
#
# Computer Card :
# 2 of Clubs ♣
#
# You won this round!
#
# ----
# You have 44 cards on your deck
# The computer has 8 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Hearts ♥
#
# Computer Card :
# 8 of Diamonds ♦
#
# You won this round!
#
# ----
# You have 45 cards on your deck
# The computer has 7 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 7 of Clubs ♣
#
# Computer Card :
# 8 of Clubs ♣
#
# The computer won this round!
#
# ----
# You have 44 cards on your deck
# The computer has 8 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Spades ♠
#
# Computer Card :
# 5 of Hearts ♥
#
# You won this round!
#
# ----
# You have 45 cards on your deck
# The computer has 7 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Spades ♠
#
# Computer Card :
# 7 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 44 cards on your deck
# The computer has 8 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Diamonds ♦
#
# Computer Card :
# Queen of Clubs ♣
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# Queen of Hearts ♥
#
# Computer Card :
# 7 of Clubs ♣
#
# You won this round!
#
# ----
# You have 49 cards on your deck
# The computer has 3 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Spades ♠
#
# Computer Card :
# 8 of Clubs ♣
#
# You won this round!
#
# ----
# You have 50 cards on your deck
# The computer has 2 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Spades ♠
#
# Computer Card :
# 4 of Spades ♠
#
# You won this round!
#
# ----
# You have 51 cards on your deck
# The computer has 1 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 4 of Hearts ♥
#
# Computer Card :
# 7 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 50 cards on your deck
# The computer has 2 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 9 of Diamonds ♦
#
# Computer Card :
# 4 of Hearts ♥
#
# You won this round!
#
# ----
# You have 51 cards on your deck
# The computer has 1 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 5 of Clubs ♣
#
# Computer Card :
# 7 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 50 cards on your deck
# The computer has 2 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 8 of Spades ♠
#
# Computer Card :
# 5 of Clubs ♣
#
# You won this round!
#
# ----
# You have 51 cards on your deck
# The computer has 1 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Clubs ♣
#
# Computer Card :
# 7 of Diamonds ♦
#
# The computer won this round!
#
# ----
# You have 50 cards on your deck
# The computer has 2 cards on its deck
# ----
#
#  === Let's Start the war ===
#
# Your Card :
# 3 of Hearts ♥
#
# Computer Card :
# 3 of Clubs ♣
#
# It's a Tie!. This is War !
# Six Hidden Cards : XXX XXX
#
#  === Let's Start the war ===
#
# Your Card :
# 2 of Hearts ♥
#
# Computer Card :
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 242
#     239 game.print_welcome_message()
#     241 while not game.check_game_over():
# --> 242     game.start_battle()
#     243     game.print_stats()
#
# Cell In[2], line 165, in WarCardGame.start_battle(self, cards_from_war)
#     163 else:
#     164     print("\nIt's a Tie!. This is War !")
# --> 165     self.start_war(cards_won)
#     167 return winner
#
# Cell In[2], line 201, in WarCardGame.start_war(self, cards_from_war)
#     197     computer_cards.append(computer_card)
#     199 print(f"Six Hidden Cards : XXX XXX")
# --> 201 self.start_battle(player_cards + computer_cards + cards_from_war)
#
# Cell In[2], line 150, in WarCardGame.start_battle(self, cards_from_war)
#     147 player_card.show()
#     149 print("\nComputer Card : ")
# --> 150 computer_card.show()
#     152 winner = self.get_round_winner(player_card, computer_card)
#     153 cards_won = self.get_cards_won(player_card,computer_card, cards_from_war)
#
# AttributeError: 'NoneType' object has no attribute 'show'
